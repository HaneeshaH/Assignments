# %%
import requests
import pandas as pd
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data=resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36282',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36282/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36282/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36282/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36282',
#   'id': 698753726,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0NTY3Nzc0',
#   'number': 36282,
#   'title': 'REF: de-duplicate _wrap_joined_index',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-11T02:47:46Z',
#   'updated_at': '2020-09-11T02:47:46Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36282',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36282',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36282.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36282.patch'},
#   'body': '',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36281',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36281/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36281/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36281/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/36281',
#   'id': 698751134,
#   'node_id': 'MDU6SXNzdWU2OTg3NTExMzQ=',
#   'number': 36281,
#   'title': 'QST: Appending to pandas DataFrames',
#   'user': {'login': 'wumpus',
#    'id': 2142266,
#    'node_id': 'MDQ6VXNlcjIxNDIyNjY=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/2142266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wumpus',
#    'html_url': 'https://github.com/wumpus',
#    'followers_url': 'https://api.github.com/users/wumpus/followers',
#    'following_url': 'https://api.github.com/users/wumpus/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wumpus/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wumpus/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wumpus/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wumpus/orgs',
#    'repos_url': 'https://api.github.com/users/wumpus/repos',
#    'events_url': 'https://api.github.com/users/wumpus/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wumpus/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-11T02:44:08Z',
#   'updated_at': '2020-09-11T02:44:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': 'Like a lot of people, I wrote some code that attempted to call `DataFrame.append()` a few million times, and it was slow. So I read the pandas docs ("don\'t do that, use `pd.concat()`") and StackOverflow (blah blah blah Ginger) and decided that if I was going to write a function that made chunks of dataframe and then concatenated them, the least I could do would be to make it general purpose, and a package others could use.\r\n\r\nThus I created [pandas-appender](https://github.com/wumpus/pandas-appender).\r\n\r\nIt has some features that I care about -- scalability to 100s of millions of rows, and features that help specify or identify categorical columns. But of course, it\'s not quite compatible with `DataFrame.append()`, and I\'m new enough to pandas to be unsure if I\'ve made it follow pandas conventions as far as possible.\r\n\r\nSo my question is, can someone who is better versed in pandas conventions than I am, preferably someone who would love to use a package that let them easily build up a dataframe with `.append()`, take a look at this code and give me some advice?\r\n\r\nThanks in advance!\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36280',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36280/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36280/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36280/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36280',
#   'id': 698713545,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0NTMxMzQ1',
#   'number': 36280,
#   'title': 'PERF: CategoricalDtype.__eq__',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-11T01:52:01Z',
#   'updated_at': '2020-09-11T01:52:01Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36280',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36280',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36280.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36280.patch'},
#   'body': 'Three special cases where we can get better performance\r\n\r\n1) categories have different lengths --> never equal\r\n2) categories have different dtypes --> never equal\r\n3) categories are not object-dtype --> can use use get_indexer instead of hashing\r\n\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\ndti = pd.date_range("2016-01-01", periods=10000, tz="US/Pacific")\r\ndti2 = type(dti)(dti._data.copy())\r\n\r\nnp.random.shuffle(dti._data._data)\r\nassert not dti.equals(dti2)\r\n\r\ncd1 = pd.CategoricalDtype(dti)\r\ncd2 = pd.CategoricalDtype(dti2)\r\ncd3 = pd.CategoricalDtype(dti2[:-1])\r\ncd4 = pd.CategoricalDtype(pd.Index(range(len(dti))))\r\n\r\nIn [5]: %timeit cd1 == cd2 \r\n548 µs ± 3.94 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)  # <-- master\r\n239 µs ± 1.04 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)  # <-- PR\r\n\r\nIn [6]: %timeit cd1 == cd3\r\n543 µs ± 4.05 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)   # <-- master\r\n5.05 µs ± 257 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each) # <-- PR\r\n\r\nIn [7]: %timeit cd1 == cd4\r\n389 µs ± 13.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)  # <-- master\r\n2.17 µs ± 63.1 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)  # <-- PR\r\n\r\n```',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36279',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36279/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36279/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36279/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/36279',
#   'id': 698560986,
#   'node_id': 'MDU6SXNzdWU2OTg1NjA5ODY=',
#   'number': 36279,
#   'title': 'QST: Python 3.9 testing in CI',
#   'user': {'login': 'wumpus',
#    'id': 2142266,
#    'node_id': 'MDQ6VXNlcjIxNDIyNjY=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/2142266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wumpus',
#    'html_url': 'https://github.com/wumpus',
#    'followers_url': 'https://api.github.com/users/wumpus/followers',
#    'following_url': 'https://api.github.com/users/wumpus/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wumpus/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wumpus/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wumpus/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wumpus/orgs',
#    'repos_url': 'https://api.github.com/users/wumpus/repos',
#    'events_url': 'https://api.github.com/users/wumpus/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wumpus/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2020-09-10T22:23:16Z',
#   'updated_at': '2020-09-11T01:23:26Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "I use Travis CI to test, and I've tested all of my projects against the upcoming python 3.9 release. The only problem I'm seeing is dependent packages is pandas.\r\n\r\nPandas + 3.9 takes a long time to build and then dies with a compiler error. It also does this when I install cython first, which is the usual workaround when a new version of Python is close to release. Is some not-yet-mainstream cython version needed? I suppose there will be a wheel by the time 3.9.0 comes out in October?\r\n\r\nExample CI log: https://travis-ci.com/github/wumpus/paramsurvey/jobs/383337409\r\n\r\n```\r\n  pandas/_libs/writers.c:4942:5: error: â€˜_PyUnicode_get_wstr_lengthâ€™ is deprecated [-Werror=deprecated-declarations]\r\n       __pyx_v_l = PyUnicode_GET_SIZE(__pyx_v_val);\r\n       ^\r\n  In file included from /opt/python/3.9-dev/include/python3.9/unicodeobject.h:1026:0,\r\n                   from /opt/python/3.9-dev/include/python3.9/Python.h:97,\r\n                   from pandas/_libs/writers.c:33:\r\n  /opt/python/3.9-dev/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here\r\n   static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {\r\n                            ^\r\n  pandas/_libs/writers.c:4942:5: error: â€˜PyUnicode_AsUnicodeâ€™ is deprecated [-Werror=deprecated-declarations]\r\n       __pyx_v_l = PyUnicode_GET_SIZE(__pyx_v_val);\r\n       ^\r\n  In file included from /opt/python/3.9-dev/include/python3.9/unicodeobject.h:1026:0,\r\n                   from /opt/python/3.9-dev/include/python3.9/Python.h:97,\r\n                   from pandas/_libs/writers.c:33:\r\n  /opt/python/3.9-dev/include/python3.9/cpython/unicodeobject.h:580:45: note: declared here\r\n   Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(\r\n                                               ^\r\n  pandas/_libs/writers.c:4942:5: error: â€˜_PyUnicode_get_wstr_lengthâ€™ is deprecated [-Werror=deprecated-declarations]\r\n       __pyx_v_l = PyUnicode_GET_SIZE(__pyx_v_val);\r\n       ^\r\n  In file included from /opt/python/3.9-dev/include/python3.9/unicodeobject.h:1026:0,\r\n                   from /opt/python/3.9-dev/include/python3.9/Python.h:97,\r\n                   from pandas/_libs/writers.c:33:\r\n  /opt/python/3.9-dev/include/python3.9/cpython/unicodeobject.h:446:26: note: declared here\r\n   static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {\r\n                            ^\r\n  cc1: all warnings being treated as errors\r\n  error: command '/usr/bin/gcc' failed with exit code 1\r\n```\r\n\r\nThe logfile contains complete version information about the travisci environment.",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36278',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36278/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36278/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36278/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36278',
#   'id': 698528739,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0MzYyMjYz',
#   'number': 36278,
#   'title': '[TST]: Add test for 24768',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2020-09-10T21:46:06Z',
#   'updated_at': '2020-09-10T22:26:18Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36278',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36278',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36278.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36278.patch'},
#   'body': '- [x] closes #24768\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n\r\n\r\nIssue was fixed in the past.\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36277',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36277/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36277/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36277/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36277',
#   'id': 698509860,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0MzQ1MTY4',
#   'number': 36277,
#   'title': 'ENH: add peek function',
#   'user': {'login': 'Quetzalcohuatl',
#    'id': 22649802,
#    'node_id': 'MDQ6VXNlcjIyNjQ5ODAy',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/22649802?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Quetzalcohuatl',
#    'html_url': 'https://github.com/Quetzalcohuatl',
#    'followers_url': 'https://api.github.com/users/Quetzalcohuatl/followers',
#    'following_url': 'https://api.github.com/users/Quetzalcohuatl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Quetzalcohuatl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Quetzalcohuatl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Quetzalcohuatl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Quetzalcohuatl/orgs',
#    'repos_url': 'https://api.github.com/users/Quetzalcohuatl/repos',
#    'events_url': 'https://api.github.com/users/Quetzalcohuatl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Quetzalcohuatl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2020-09-10T21:25:00Z',
#   'updated_at': '2020-09-10T22:27:46Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36277',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36277',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36277.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36277.patch'},
#   'body': '- [x]  closes #18691\r\n- [x] tests added / passed\r\n- [ ] passes black pandas\r\n- [ ] passes git diff upstream/master -u -- "*.py" | flake8 --diff\r\n- [x] whatsnew entry\r\n\r\nadded peek, which is essentially a concatenation of head and tail functions. The reason I add, is because often for sorted data, you are interested in looking at both the head and tail simultaneously to see the min/max range.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36276',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36276/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36276/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36276/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36276',
#   'id': 698477454,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0MzE2MDE0',
#   'number': 36276,
#   'title': 'CLN: typo cleanups',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#    'id': 5479819,
#    'node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#    'number': 73,
#    'title': '1.2',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 56,
#    'closed_issues': 337,
#    'state': 'open',
#    'created_at': '2020-05-29T23:47:32Z',
#    'updated_at': '2020-09-11T03:02:08Z',
#    'due_on': '2020-11-29T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2020-09-10T20:50:05Z',
#   'updated_at': '2020-09-10T21:47:24Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36276',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36276',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36276.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36276.patch'},
#   'body': '',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36275',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36275/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36275/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36275/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36275',
#   'id': 698461537,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0MzAyMTUx',
#   'number': 36275,
#   'title': 'Fix #35484 - re-allow sqlalchemy declarative system to use `%` in read_sql.',
#   'user': {'login': 'machow',
#    'id': 2574498,
#    'node_id': 'MDQ6VXNlcjI1NzQ0OTg=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/2574498?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/machow',
#    'html_url': 'https://github.com/machow',
#    'followers_url': 'https://api.github.com/users/machow/followers',
#    'following_url': 'https://api.github.com/users/machow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/machow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/machow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/machow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/machow/orgs',
#    'repos_url': 'https://api.github.com/users/machow/repos',
#    'events_url': 'https://api.github.com/users/machow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/machow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-10T20:33:13Z',
#   'updated_at': '2020-09-10T20:45:20Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36275',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36275',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36275.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36275.patch'},
#   'body': '- [x] closes #35484\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n\r\n* Adds tests to cover sql cases combining parameters and `%`.\r\n* Notably, these tests highlight two regressions in v1.1\r\n  - `pd.read_sql("SELECT 1 %% 2", engine)` fails. See #35871.\r\n  - `pd.read_sql(sqlalchemy.sql.text("SELECT 1 % 2"), engine)` fails. See #35484.\r\n* Fixes second issue by modifying SqlDatabase to not use `no_parameter`, and wrapping string queries in `sql.text()` when no parameters are passed.\r\n\r\nI was going nuts trying to keep track of all the cases, so tossed them into a table! I didn\'t have time to explicitly check v1.05, so would be helpful if someone could verify that column (or I may be able to loop back to it)!\r\n\r\n| query |   v1.05 | v.1.1 | PR | issue |\r\n| --- | --- | --- | --- | --- |\r\n| no params, `%` | ❌ | ✅ | ✅ | #34211 (merged) |\r\n| no params, `%%` | ✅ | ❌ | ❌ | #35871 |\r\n| params, `%` | ❌ | ❌ | ❌ |  https://github.com/psycopg/psycopg2/issues/827 |\r\n| params, `%%` | ✅ | ✅ | ✅ | | \r\n| sqla declarative, `%` | ✅ | ❌ | ✅ | #35484 |',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36274',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36274/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36274/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36274/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36274',
#   'id': 698328890,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0MTgzMjc4',
#   'number': 36274,
#   'title': 'REF: implement Categorical._validate_listlike',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-10T18:21:12Z',
#   'updated_at': '2020-09-10T18:21:12Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36274',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36274',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36274.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36274.patch'},
#   'body': "I found it really confusing why we used slightly different dtype-comparisons in a bunch of different places (e.g CategoricalIndex.get_indexer vs CategoricalIndex.get_indexer_non_unique).  AFAICT It's just a matter of optimizations accruing over time without a helper method to keep them in sync. ",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36273',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36273/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36273/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36273/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36273',
#   'id': 698327511,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0MTgyMDE4',
#   'number': 36273,
#   'title': 'Fix issue #36271 to disambiguate json string',
#   'user': {'login': 'tbachlechner',
#    'id': 35582223,
#    'node_id': 'MDQ6VXNlcjM1NTgyMjIz',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/35582223?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tbachlechner',
#    'html_url': 'https://github.com/tbachlechner',
#    'followers_url': 'https://api.github.com/users/tbachlechner/followers',
#    'following_url': 'https://api.github.com/users/tbachlechner/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tbachlechner/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tbachlechner/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tbachlechner/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tbachlechner/orgs',
#    'repos_url': 'https://api.github.com/users/tbachlechner/repos',
#    'events_url': 'https://api.github.com/users/tbachlechner/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tbachlechner/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2020-09-10T18:19:56Z',
#   'updated_at': '2020-09-10T22:52:40Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36273',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36273',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36273.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36273.patch'},
#   'body': 'pd.read_json() fails currently for strings that look like fsspec_url and contain "://". adding another condition to fix this at least in most cases\r\n\r\n- [X] closes #36271\r\n- [ ] tests added / passed\r\n- [ ] passes `black pandas`\r\n- [ ] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36272',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36272/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36272/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36272/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36272',
#   'id': 698322671,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0MTc3NTcy',
#   'number': 36272,
#   'title': 'CI: xfail failing parquet test',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/77',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/77',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/77/labels',
#    'id': 5850626,
#    'node_id': 'MDk6TWlsZXN0b25lNTg1MDYyNg==',
#    'number': 77,
#    'title': '1.1.3',
#    'description': 'on-merge: backport to 1.1.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars0.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 38,
#    'closed_issues': 2,
#    'state': 'open',
#    'created_at': '2020-09-07T09:13:14Z',
#    'updated_at': '2020-09-10T21:49:12Z',
#    'due_on': '2020-09-29T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2020-09-10T18:15:21Z',
#   'updated_at': '2020-09-10T21:49:19Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36272',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36272',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36272.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36272.patch'},
#   'body': '',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36271',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36271/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36271/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36271/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/36271',
#   'id': 698313542,
#   'node_id': 'MDU6SXNzdWU2OTgzMTM1NDI=',
#   'number': 36271,
#   'title': 'BUG: since pandas==1.1.0  pd.read_json() fails for strings that look similar to fsspec_url',
#   'user': {'login': 'tbachlechner',
#    'id': 35582223,
#    'node_id': 'MDQ6VXNlcjM1NTgyMjIz',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/35582223?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tbachlechner',
#    'html_url': 'https://github.com/tbachlechner',
#    'followers_url': 'https://api.github.com/users/tbachlechner/followers',
#    'following_url': 'https://api.github.com/users/tbachlechner/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tbachlechner/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tbachlechner/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tbachlechner/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tbachlechner/orgs',
#    'repos_url': 'https://api.github.com/users/tbachlechner/repos',
#    'events_url': 'https://api.github.com/users/tbachlechner/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tbachlechner/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-10T18:07:31Z',
#   'updated_at': '2020-09-11T02:40:34Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [X] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ninput_json = \'[{"0":"this is a string ://"}]\'\r\n\r\nprint(\'Input json string: {}\'.format(input_json))\r\nprint(\'URL? {}\'.format(str(pd.io.common.is_url(input_json))))\r\nprint(\'fsspec? {}\'.format(str(pd.io.common.is_fsspec_url(input_json))))\r\n\r\nprint(pd.read_json(input_json))\r\n```\r\n\r\noutput:\r\n```\r\nInput json string: [{"0":"this is a string ://"}]\r\nURL? False\r\nfsspec? True\r\n---------------------------------------------------------------------------\r\n\r\nImportError                               Traceback (most recent call last)\r\n\r\n<ipython-input-1-f3bc94ba133f> in <module>\r\n      7 print(\'fsspec? {}\'.format(str(pd.io.common.is_fsspec_url(input_json))))\r\n      8 \r\n----> 9 pd.read_json(input_json)\r\n\r\n~/miniconda3/envs/eltest/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)\r\n    197                 else:\r\n    198                     kwargs[new_arg_name] = new_arg_value\r\n--> 199             return func(*args, **kwargs)\r\n    200 \r\n    201         return cast(F, wrapper)\r\n\r\n~/miniconda3/envs/eltest/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)\r\n    294                 )\r\n    295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)\r\n--> 296             return func(*args, **kwargs)\r\n    297 \r\n    298         return wrapper\r\n\r\n~/miniconda3/envs/eltest/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)\r\n    592     compression = infer_compression(path_or_buf, compression)\r\n    593     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(\r\n--> 594         path_or_buf, encoding=encoding, compression=compression\r\n    595     )\r\n    596 \r\n\r\n~/miniconda3/envs/eltest/lib/python3.7/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)\r\n    201         if filepath_or_buffer.startswith("s3n://"):\r\n    202             filepath_or_buffer = filepath_or_buffer.replace("s3n://", "s3://")\r\n--> 203         fsspec = import_optional_dependency("fsspec")\r\n    204 \r\n    205         # If botocore is installed we fallback to reading with anon=True\r\n\r\n~/miniconda3/envs/eltest/lib/python3.7/site-packages/pandas/compat/_optional.py in import_optional_dependency(name, extra, raise_on_missing, on_version)\r\n    108     except ImportError:\r\n    109         if raise_on_missing:\r\n--> 110             raise ImportError(msg) from None\r\n    111         else:\r\n    112             return None\r\n\r\nImportError: Missing optional dependency \'fsspec\'.  Use pip or conda to install fsspec.\r\n```\r\n\r\n#### Problem description\r\n\r\nThe method `pd.read_json()` is widely used and accepts either a path or a json string. Since pandas==1.1.0 passing a string containing a json input is often interpreted as a fssspec_url and results in an error.\r\n\r\n#### Expected Output\r\n\r\n```\r\nInput json string: [{"0":"this is a string ://"}]\r\nURL? False\r\nfsspec? False\r\n                       0\r\n0  this is a string ://\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2a7d3326dee660824a8433ffd01065f8ac37f7d6\r\npython           : 3.7.7.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.15.0-112-generic\r\nVersion          : #113-Ubuntu ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36269',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36269/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36269/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36269/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36269',
#   'id': 698205610,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg0MDcyMzU3',
#   'number': 36269,
#   'title': 'CLN: pandas/io/parsers.py',
#   'user': {'login': 'ivanovmg',
#    'id': 41443370,
#    'node_id': 'MDQ6VXNlcjQxNDQzMzcw',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/41443370?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivanovmg',
#    'html_url': 'https://github.com/ivanovmg',
#    'followers_url': 'https://api.github.com/users/ivanovmg/followers',
#    'following_url': 'https://api.github.com/users/ivanovmg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ivanovmg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ivanovmg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ivanovmg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ivanovmg/orgs',
#    'repos_url': 'https://api.github.com/users/ivanovmg/repos',
#    'events_url': 'https://api.github.com/users/ivanovmg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ivanovmg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-10T16:26:00Z',
#   'updated_at': '2020-09-11T04:08:33Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36269',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36269',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36269.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36269.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n\r\nSlight clean-up of ``pandas/io/parsers.py``.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36267',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36267/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36267/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36267/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/36267',
#   'id': 698065702,
#   'node_id': 'MDU6SXNzdWU2OTgwNjU3MDI=',
#   'number': 36267,
#   'title': 'ENH: short caption for LaTeX tables',
#   'user': {'login': 'ivanovmg',
#    'id': 41443370,
#    'node_id': 'MDQ6VXNlcjQxNDQzMzcw',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/41443370?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivanovmg',
#    'html_url': 'https://github.com/ivanovmg',
#    'followers_url': 'https://api.github.com/users/ivanovmg/followers',
#    'following_url': 'https://api.github.com/users/ivanovmg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ivanovmg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ivanovmg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ivanovmg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ivanovmg/orgs',
# ...
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-09T19:44:52Z',
#   'updated_at': '2020-09-09T19:45:33Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36254',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36254',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36254.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36254.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36252',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36252/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36252/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36252/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/36252',
#   'id': 697037741,
#   'node_id': 'MDU6SXNzdWU2OTcwMzc3NDE=',
#   'number': 36252,
#   'title': 'BUG: timeseries plot x-axis starts way off when one column is all NaNs',
#   'user': {'login': 'gabrielecalvo',
#    'id': 24496457,
#    'node_id': 'MDQ6VXNlcjI0NDk2NDU3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/24496457?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gabrielecalvo',
#    'html_url': 'https://github.com/gabrielecalvo',
#    'followers_url': 'https://api.github.com/users/gabrielecalvo/followers',
#    'following_url': 'https://api.github.com/users/gabrielecalvo/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gabrielecalvo/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gabrielecalvo/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gabrielecalvo/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gabrielecalvo/orgs',
#    'repos_url': 'https://api.github.com/users/gabrielecalvo/repos',
#    'events_url': 'https://api.github.com/users/gabrielecalvo/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gabrielecalvo/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-09T18:12:27Z',
#   'updated_at': '2020-09-09T18:12:27Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n#### Code Sample\r\n```python\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\npd.DataFrame(dict(\r\n    a=[np.nan, np.nan],\r\n    b=[1, 2],\r\n    ts = [pd.Timestamp('2020-01-01'), pd.Timestamp('2020-02-02')]\r\n)).set_index('ts').plot()\r\n```\r\n\r\n#### Problem description\r\n\r\nThe x-axis (time axis) start in before 2000 where it really should start at 2020-01-01\r\n\r\n![image](https://user-images.githubusercontent.com/24496457/92637100-51570c00-f2d0-11ea-9a1d-db0a3d9785a7.png)\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2a7d3326dee660824a8433ffd01065f8ac37f7d6\r\npython           : 3.8.5.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.18362\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 142 Stepping 9, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United Kingdom.1252\r\n\r\npandas           : 1.1.2\r\nnumpy            : 1.19.1\r\npytz             : 2020.1\r\ndateutil         : 2.8.1\r\npip              : 20.2.3\r\nsetuptools       : 49.6.0.post20200814\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.1\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npytables         : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36251',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36251/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36251/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36251/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/36251',
#   'id': 697029724,
#   'node_id': 'MDU6SXNzdWU2OTcwMjk3MjQ=',
#   'number': 36251,
#   'title': 'DOC: slicing with labels when index has duplicate labels',
#   'user': {'login': 'notestaff',
#    'id': 1517155,
#    'node_id': 'MDQ6VXNlcjE1MTcxNTU=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/1517155?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/notestaff',
#    'html_url': 'https://github.com/notestaff',
#    'followers_url': 'https://api.github.com/users/notestaff/followers',
#    'following_url': 'https://api.github.com/users/notestaff/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/notestaff/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/notestaff/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/notestaff/subscriptions',
#    'organizations_url': 'https://api.github.com/users/notestaff/orgs',
#    'repos_url': 'https://api.github.com/users/notestaff/repos',
#    'events_url': 'https://api.github.com/users/notestaff/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/notestaff/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2020-09-09T17:59:08Z',
#   'updated_at': '2020-09-10T00:45:30Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Location of the documentation\r\n\r\nhttps://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#slicing-ranges\r\n\r\n**Note**: You can check the latest versions of the docs on `master` [here](https://pandas.pydata.org/docs/dev/).\r\n\r\n#### Documentation problem\r\n\r\nDocumentation doesn't specify what happens when you slice an index that has duplicates.  Does it denote the range from the first occurrence of the start element, to the last occurrence of the end element?\r\n\r\n#### Suggested fix for documentation\r\n\r\nClarify how slicing interacts with non-unique index elements.\r\n\r\nI would also emphasize, at \r\nhttps://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#slicing-with-labels\r\nthat the actual values of the index labels, and their natural comparison order and the elements between them in that natural order, do _not_ matter for slicing; i.e. that a slice of 'Z':'A' is not empty but depends on the positions that the labels denote in the array.   In all current documentation examples, the label denoting the start of the slice end also happens to be lexicographically smaller than the label denoting the end of the slice, which can mislead readers into thinking the natural order of the labels has some meaning, when all they do is denote integer positions.\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36250',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36250/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36250/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36250/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36250',
#   'id': 697021364,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDgzMDE5NzEw',
#   'number': 36250,
#   'title': 'CLN: simplify Categorical comparisons',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-09T17:45:09Z',
#   'updated_at': '2020-09-09T17:45:09Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36250',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36250',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36250.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36250.patch'},
#   'body': 'We have way too many ways of comparing Categorical dtypes.\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36249',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36249/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36249/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36249/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36249',
#   'id': 696963630,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDgyOTY5MjYx',
#   'number': 36249,
#   'title': 'BUG: na parameter for str.startswith and str.endswith not propagating for Series with categorical dtype',
#   'user': {'login': 'asishm',
#    'id': 1978117,
#    'node_id': 'MDQ6VXNlcjE5NzgxMTc=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1978117?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asishm',
#    'html_url': 'https://github.com/asishm',
#    'followers_url': 'https://api.github.com/users/asishm/followers',
#    'following_url': 'https://api.github.com/users/asishm/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/asishm/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/asishm/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/asishm/subscriptions',
#    'organizations_url': 'https://api.github.com/users/asishm/orgs',
#    'repos_url': 'https://api.github.com/users/asishm/repos',
#    'events_url': 'https://api.github.com/users/asishm/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/asishm/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'},
#    {'id': 57522093,
#     'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings',
#     'name': 'Strings',
#     'color': '5319e7',
#     'default': False,
#     'description': 'String extension data type and string data'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2020-09-09T16:31:45Z',
#   'updated_at': '2020-09-11T01:01:56Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36249',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/36249',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/36249.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/36249.patch'},
#   'body': '- [x] closes #36241\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n\r\nI parametrized dtype in existing tests. Should I create a separate test instead?',
#   'performed_via_github_app': None}]

# %%
dict={'login': 'jbrockmendel',
   'id': 8078968,
   'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
   'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
   'gravatar_id': '',
   'url': 'https://api.github.com/users/jbrockmendel',
   'html_url': 'https://github.com/jbrockmendel',
   'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
   'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
   'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
   'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
   'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
   'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
   'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
   'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
   'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
   'type': 'User',
   'site_admin': False}

# %%
data[0]['user']
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
df1=pd.DataFrame()
for i in range(len(data)):
    row=pd.DataFrame(data[i]['user'],index=[i])
    df1=df1.append(row)
df1.add_prefix('user.')
# Out:
#         user.login   user.id          user.node_id  \
# 0     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1           wumpus   2142266  MDQ6VXNlcjIxNDIyNjY=
# 2     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3           wumpus   2142266  MDQ6VXNlcjIxNDIyNjY=
# 4            phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 5   Quetzalcohuatl  22649802  MDQ6VXNlcjIyNjQ5ODAy
# 6     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 7           machow   2574498  MDQ6VXNlcjI1NzQ0OTg=
# 8     jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 9     tbachlechner  35582223  MDQ6VXNlcjM1NTgyMjIz
# 10    jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 11    tbachlechner  35582223  MDQ6VXNlcjM1NTgyMjIz
# 12        ivanovmg  41443370  MDQ6VXNlcjQxNDQzMzcw
# 13        ivanovmg  41443370  MDQ6VXNlcjQxNDQzMzcw
# 14        Hanspagh   1024416  MDQ6VXNlcjEwMjQ0MTY=
# 15          xhochy     70274      MDQ6VXNlcjcwMjc0
# 16          Flix6x  30658763  MDQ6VXNlcjMwNjU4NzYz
# 17      xuancong84  10172392  MDQ6VXNlcjEwMTcyMzky
# 18          eromoe   3938751  MDQ6VXNlcjM5Mzg3NTE=
# 19    jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 20      rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
# 21    jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 22           phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 23           phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 24           phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 25    jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 26   gabrielecalvo  24496457  MDQ6VXNlcjI0NDk2NDU3
# 27       notestaff   1517155  MDQ6VXNlcjE1MTcxNTU=
# 28    jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 29          asishm   1978117  MDQ6VXNlcjE5NzgxMTc=
#
#                                       user.avatar_url user.gravatar_id  \
# 0   https://avatars1.githubusercontent.com/u/80789...
# 1   https://avatars1.githubusercontent.com/u/21422...
# 2   https://avatars1.githubusercontent.com/u/80789...
# 3   https://avatars1.githubusercontent.com/u/21422...
# 4   https://avatars1.githubusercontent.com/u/61934...
# 5   https://avatars1.githubusercontent.com/u/22649...
# 6   https://avatars1.githubusercontent.com/u/80789...
# 7   https://avatars3.githubusercontent.com/u/25744...
# 8   https://avatars1.githubusercontent.com/u/80789...
# 9   https://avatars1.githubusercontent.com/u/35582...
# 10  https://avatars1.githubusercontent.com/u/80789...
# 11  https://avatars1.githubusercontent.com/u/35582...
# 12  https://avatars3.githubusercontent.com/u/41443...
# 13  https://avatars3.githubusercontent.com/u/41443...
# 14  https://avatars1.githubusercontent.com/u/10244...
# 15  https://avatars2.githubusercontent.com/u/70274...
# 16  https://avatars2.githubusercontent.com/u/30658...
# 17  https://avatars0.githubusercontent.com/u/10172...
# 18  https://avatars1.githubusercontent.com/u/39387...
# 19  https://avatars1.githubusercontent.com/u/80789...
# 20  https://avatars1.githubusercontent.com/u/45562...
# 21  https://avatars1.githubusercontent.com/u/80789...
# 22  https://avatars1.githubusercontent.com/u/61934...
# 23  https://avatars1.githubusercontent.com/u/61934...
# 24  https://avatars1.githubusercontent.com/u/61934...
# 25  https://avatars1.githubusercontent.com/u/80789...
# 26  https://avatars3.githubusercontent.com/u/24496...
# 27  https://avatars2.githubusercontent.com/u/15171...
# 28  https://avatars1.githubusercontent.com/u/80789...
# 29  https://avatars0.githubusercontent.com/u/19781...
#
#                                        user.url  \
# 0     https://api.github.com/users/jbrockmendel
# 1           https://api.github.com/users/wumpus
# 2     https://api.github.com/users/jbrockmendel
# 3           https://api.github.com/users/wumpus
# 4            https://api.github.com/users/phofl
# 5   https://api.github.com/users/Quetzalcohuatl
# 6     https://api.github.com/users/jbrockmendel
# 7           https://api.github.com/users/machow
# 8     https://api.github.com/users/jbrockmendel
# 9     https://api.github.com/users/tbachlechner
# 10    https://api.github.com/users/jbrockmendel
# 11    https://api.github.com/users/tbachlechner
# 12        https://api.github.com/users/ivanovmg
# 13        https://api.github.com/users/ivanovmg
# 14        https://api.github.com/users/Hanspagh
# 15          https://api.github.com/users/xhochy
# 16          https://api.github.com/users/Flix6x
# 17      https://api.github.com/users/xuancong84
# 18          https://api.github.com/users/eromoe
# 19    https://api.github.com/users/jbrockmendel
# 20      https://api.github.com/users/rhshadrach
# 21    https://api.github.com/users/jbrockmendel
# 22           https://api.github.com/users/phofl
# 23           https://api.github.com/users/phofl
# 24           https://api.github.com/users/phofl
# 25    https://api.github.com/users/jbrockmendel
# 26   https://api.github.com/users/gabrielecalvo
# 27       https://api.github.com/users/notestaff
# 28    https://api.github.com/users/jbrockmendel
# 29          https://api.github.com/users/asishm
#
#                         user.html_url  \
# 0     https://github.com/jbrockmendel
# 1           https://github.com/wumpus
# 2     https://github.com/jbrockmendel
# 3           https://github.com/wumpus
# 4            https://github.com/phofl
# 5   https://github.com/Quetzalcohuatl
# 6     https://github.com/jbrockmendel
# 7           https://github.com/machow
# 8     https://github.com/jbrockmendel
# 9     https://github.com/tbachlechner
# 10    https://github.com/jbrockmendel
# 11    https://github.com/tbachlechner
# 12        https://github.com/ivanovmg
# 13        https://github.com/ivanovmg
# 14        https://github.com/Hanspagh
# 15          https://github.com/xhochy
# 16          https://github.com/Flix6x
# 17      https://github.com/xuancong84
# 18          https://github.com/eromoe
# 19    https://github.com/jbrockmendel
# 20      https://github.com/rhshadrach
# 21    https://github.com/jbrockmendel
# 22           https://github.com/phofl
# 23           https://github.com/phofl
# 24           https://github.com/phofl
# 25    https://github.com/jbrockmendel
# 26   https://github.com/gabrielecalvo
# 27       https://github.com/notestaff
# 28    https://github.com/jbrockmendel
# 29          https://github.com/asishm
#
#                                    user.followers_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1       https://api.github.com/users/wumpus/followers
# 2   https://api.github.com/users/jbrockmendel/foll...
# 3       https://api.github.com/users/wumpus/followers
# 4        https://api.github.com/users/phofl/followers
# 5   https://api.github.com/users/Quetzalcohuatl/fo...
# 6   https://api.github.com/users/jbrockmendel/foll...
# 7       https://api.github.com/users/machow/followers
# 8   https://api.github.com/users/jbrockmendel/foll...
# 9   https://api.github.com/users/tbachlechner/foll...
# 10  https://api.github.com/users/jbrockmendel/foll...
# 11  https://api.github.com/users/tbachlechner/foll...
# 12    https://api.github.com/users/ivanovmg/followers
# 13    https://api.github.com/users/ivanovmg/followers
# 14    https://api.github.com/users/Hanspagh/followers
# 15      https://api.github.com/users/xhochy/followers
# 16      https://api.github.com/users/Flix6x/followers
# 17  https://api.github.com/users/xuancong84/followers
# 18      https://api.github.com/users/eromoe/followers
# 19  https://api.github.com/users/jbrockmendel/foll...
# 20  https://api.github.com/users/rhshadrach/followers
# 21  https://api.github.com/users/jbrockmendel/foll...
# 22       https://api.github.com/users/phofl/followers
# 23       https://api.github.com/users/phofl/followers
# 24       https://api.github.com/users/phofl/followers
# 25  https://api.github.com/users/jbrockmendel/foll...
# 26  https://api.github.com/users/gabrielecalvo/fol...
# 27   https://api.github.com/users/notestaff/followers
# 28  https://api.github.com/users/jbrockmendel/foll...
# 29      https://api.github.com/users/asishm/followers
#
#                                    user.following_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/wumpus/following{...
# 2   https://api.github.com/users/jbrockmendel/foll...
# 3   https://api.github.com/users/wumpus/following{...
# 4   https://api.github.com/users/phofl/following{/...
# 5   https://api.github.com/users/Quetzalcohuatl/fo...
# 6   https://api.github.com/users/jbrockmendel/foll...
# 7   https://api.github.com/users/machow/following{...
# 8   https://api.github.com/users/jbrockmendel/foll...
# 9   https://api.github.com/users/tbachlechner/foll...
# 10  https://api.github.com/users/jbrockmendel/foll...
# 11  https://api.github.com/users/tbachlechner/foll...
# 12  https://api.github.com/users/ivanovmg/followin...
# 13  https://api.github.com/users/ivanovmg/followin...
# 14  https://api.github.com/users/Hanspagh/followin...
# 15  https://api.github.com/users/xhochy/following{...
# 16  https://api.github.com/users/Flix6x/following{...
# 17  https://api.github.com/users/xuancong84/follow...
# 18  https://api.github.com/users/eromoe/following{...
# 19  https://api.github.com/users/jbrockmendel/foll...
# 20  https://api.github.com/users/rhshadrach/follow...
# 21  https://api.github.com/users/jbrockmendel/foll...
# 22  https://api.github.com/users/phofl/following{/...
# 23  https://api.github.com/users/phofl/following{/...
# 24  https://api.github.com/users/phofl/following{/...
# 25  https://api.github.com/users/jbrockmendel/foll...
# 26  https://api.github.com/users/gabrielecalvo/fol...
# 27  https://api.github.com/users/notestaff/followi...
# 28  https://api.github.com/users/jbrockmendel/foll...
# 29  https://api.github.com/users/asishm/following{...
#
#                                        user.gists_url  \
# 0   https://api.github.com/users/jbrockmendel/gist...
# 1   https://api.github.com/users/wumpus/gists{/gis...
# 2   https://api.github.com/users/jbrockmendel/gist...
# 3   https://api.github.com/users/wumpus/gists{/gis...
# 4   https://api.github.com/users/phofl/gists{/gist...
# 5   https://api.github.com/users/Quetzalcohuatl/gi...
# 6   https://api.github.com/users/jbrockmendel/gist...
# 7   https://api.github.com/users/machow/gists{/gis...
# 8   https://api.github.com/users/jbrockmendel/gist...
# 9   https://api.github.com/users/tbachlechner/gist...
# 10  https://api.github.com/users/jbrockmendel/gist...
# 11  https://api.github.com/users/tbachlechner/gist...
# 12  https://api.github.com/users/ivanovmg/gists{/g...
# 13  https://api.github.com/users/ivanovmg/gists{/g...
# 14  https://api.github.com/users/Hanspagh/gists{/g...
# 15  https://api.github.com/users/xhochy/gists{/gis...
# 16  https://api.github.com/users/Flix6x/gists{/gis...
# 17  https://api.github.com/users/xuancong84/gists{...
# 18  https://api.github.com/users/eromoe/gists{/gis...
# 19  https://api.github.com/users/jbrockmendel/gist...
# 20  https://api.github.com/users/rhshadrach/gists{...
# 21  https://api.github.com/users/jbrockmendel/gist...
# 22  https://api.github.com/users/phofl/gists{/gist...
# 23  https://api.github.com/users/phofl/gists{/gist...
# 24  https://api.github.com/users/phofl/gists{/gist...
# 25  https://api.github.com/users/jbrockmendel/gist...
# 26  https://api.github.com/users/gabrielecalvo/gis...
# 27  https://api.github.com/users/notestaff/gists{/...
# 28  https://api.github.com/users/jbrockmendel/gist...
# 29  https://api.github.com/users/asishm/gists{/gis...
#
#                                      user.starred_url  \
# 0   https://api.github.com/users/jbrockmendel/star...
# 1   https://api.github.com/users/wumpus/starred{/o...
# 2   https://api.github.com/users/jbrockmendel/star...
# 3   https://api.github.com/users/wumpus/starred{/o...
# 4   https://api.github.com/users/phofl/starred{/ow...
# 5   https://api.github.com/users/Quetzalcohuatl/st...
# 6   https://api.github.com/users/jbrockmendel/star...
# 7   https://api.github.com/users/machow/starred{/o...
# 8   https://api.github.com/users/jbrockmendel/star...
# 9   https://api.github.com/users/tbachlechner/star...
# 10  https://api.github.com/users/jbrockmendel/star...
# 11  https://api.github.com/users/tbachlechner/star...
# 12  https://api.github.com/users/ivanovmg/starred{...
# 13  https://api.github.com/users/ivanovmg/starred{...
# 14  https://api.github.com/users/Hanspagh/starred{...
# 15  https://api.github.com/users/xhochy/starred{/o...
# 16  https://api.github.com/users/Flix6x/starred{/o...
# 17  https://api.github.com/users/xuancong84/starre...
# 18  https://api.github.com/users/eromoe/starred{/o...
# 19  https://api.github.com/users/jbrockmendel/star...
# 20  https://api.github.com/users/rhshadrach/starre...
# 21  https://api.github.com/users/jbrockmendel/star...
# 22  https://api.github.com/users/phofl/starred{/ow...
# 23  https://api.github.com/users/phofl/starred{/ow...
# 24  https://api.github.com/users/phofl/starred{/ow...
# 25  https://api.github.com/users/jbrockmendel/star...
# 26  https://api.github.com/users/gabrielecalvo/sta...
# 27  https://api.github.com/users/notestaff/starred...
# 28  https://api.github.com/users/jbrockmendel/star...
# 29  https://api.github.com/users/asishm/starred{/o...
#
#                                user.subscriptions_url  \
# 0   https://api.github.com/users/jbrockmendel/subs...
# 1   https://api.github.com/users/wumpus/subscriptions
# 2   https://api.github.com/users/jbrockmendel/subs...
# 3   https://api.github.com/users/wumpus/subscriptions
# 4    https://api.github.com/users/phofl/subscriptions
# 5   https://api.github.com/users/Quetzalcohuatl/su...
# 6   https://api.github.com/users/jbrockmendel/subs...
# 7   https://api.github.com/users/machow/subscriptions
# 8   https://api.github.com/users/jbrockmendel/subs...
# 9   https://api.github.com/users/tbachlechner/subs...
# 10  https://api.github.com/users/jbrockmendel/subs...
# 11  https://api.github.com/users/tbachlechner/subs...
# 12  https://api.github.com/users/ivanovmg/subscrip...
# 13  https://api.github.com/users/ivanovmg/subscrip...
# 14  https://api.github.com/users/Hanspagh/subscrip...
# 15  https://api.github.com/users/xhochy/subscriptions
# 16  https://api.github.com/users/Flix6x/subscriptions
# 17  https://api.github.com/users/xuancong84/subscr...
# 18  https://api.github.com/users/eromoe/subscriptions
# 19  https://api.github.com/users/jbrockmendel/subs...
# 20  https://api.github.com/users/rhshadrach/subscr...
# 21  https://api.github.com/users/jbrockmendel/subs...
# 22   https://api.github.com/users/phofl/subscriptions
# 23   https://api.github.com/users/phofl/subscriptions
# 24   https://api.github.com/users/phofl/subscriptions
# 25  https://api.github.com/users/jbrockmendel/subs...
# 26  https://api.github.com/users/gabrielecalvo/sub...
# 27  https://api.github.com/users/notestaff/subscri...
# 28  https://api.github.com/users/jbrockmendel/subs...
# 29  https://api.github.com/users/asishm/subscriptions
#
#                               user.organizations_url  \
# 0     https://api.github.com/users/jbrockmendel/orgs
# 1           https://api.github.com/users/wumpus/orgs
# 2     https://api.github.com/users/jbrockmendel/orgs
# 3           https://api.github.com/users/wumpus/orgs
# 4            https://api.github.com/users/phofl/orgs
# 5   https://api.github.com/users/Quetzalcohuatl/orgs
# 6     https://api.github.com/users/jbrockmendel/orgs
# 7           https://api.github.com/users/machow/orgs
# 8     https://api.github.com/users/jbrockmendel/orgs
# 9     https://api.github.com/users/tbachlechner/orgs
# 10    https://api.github.com/users/jbrockmendel/orgs
# 11    https://api.github.com/users/tbachlechner/orgs
# 12        https://api.github.com/users/ivanovmg/orgs
# 13        https://api.github.com/users/ivanovmg/orgs
# 14        https://api.github.com/users/Hanspagh/orgs
# 15          https://api.github.com/users/xhochy/orgs
# 16          https://api.github.com/users/Flix6x/orgs
# 17      https://api.github.com/users/xuancong84/orgs
# 18          https://api.github.com/users/eromoe/orgs
# 19    https://api.github.com/users/jbrockmendel/orgs
# 20      https://api.github.com/users/rhshadrach/orgs
# 21    https://api.github.com/users/jbrockmendel/orgs
# 22           https://api.github.com/users/phofl/orgs
# 23           https://api.github.com/users/phofl/orgs
# 24           https://api.github.com/users/phofl/orgs
# 25    https://api.github.com/users/jbrockmendel/orgs
# 26   https://api.github.com/users/gabrielecalvo/orgs
# 27       https://api.github.com/users/notestaff/orgs
# 28    https://api.github.com/users/jbrockmendel/orgs
# 29          https://api.github.com/users/asishm/orgs
#
#                                        user.repos_url  \
# 0     https://api.github.com/users/jbrockmendel/repos
# 1           https://api.github.com/users/wumpus/repos
# 2     https://api.github.com/users/jbrockmendel/repos
# 3           https://api.github.com/users/wumpus/repos
# 4            https://api.github.com/users/phofl/repos
# 5   https://api.github.com/users/Quetzalcohuatl/repos
# 6     https://api.github.com/users/jbrockmendel/repos
# 7           https://api.github.com/users/machow/repos
# 8     https://api.github.com/users/jbrockmendel/repos
# 9     https://api.github.com/users/tbachlechner/repos
# 10    https://api.github.com/users/jbrockmendel/repos
# 11    https://api.github.com/users/tbachlechner/repos
# 12        https://api.github.com/users/ivanovmg/repos
# 13        https://api.github.com/users/ivanovmg/repos
# 14        https://api.github.com/users/Hanspagh/repos
# 15          https://api.github.com/users/xhochy/repos
# 16          https://api.github.com/users/Flix6x/repos
# 17      https://api.github.com/users/xuancong84/repos
# 18          https://api.github.com/users/eromoe/repos
# 19    https://api.github.com/users/jbrockmendel/repos
# 20      https://api.github.com/users/rhshadrach/repos
# 21    https://api.github.com/users/jbrockmendel/repos
# 22           https://api.github.com/users/phofl/repos
# 23           https://api.github.com/users/phofl/repos
# 24           https://api.github.com/users/phofl/repos
# 25    https://api.github.com/users/jbrockmendel/repos
# 26   https://api.github.com/users/gabrielecalvo/repos
# 27       https://api.github.com/users/notestaff/repos
# 28    https://api.github.com/users/jbrockmendel/repos
# 29          https://api.github.com/users/asishm/repos
#
#                                       user.events_url  \
# 0   https://api.github.com/users/jbrockmendel/even...
# 1   https://api.github.com/users/wumpus/events{/pr...
# 2   https://api.github.com/users/jbrockmendel/even...
# 3   https://api.github.com/users/wumpus/events{/pr...
# 4   https://api.github.com/users/phofl/events{/pri...
# 5   https://api.github.com/users/Quetzalcohuatl/ev...
# 6   https://api.github.com/users/jbrockmendel/even...
# 7   https://api.github.com/users/machow/events{/pr...
# 8   https://api.github.com/users/jbrockmendel/even...
# 9   https://api.github.com/users/tbachlechner/even...
# 10  https://api.github.com/users/jbrockmendel/even...
# 11  https://api.github.com/users/tbachlechner/even...
# 12  https://api.github.com/users/ivanovmg/events{/...
# 13  https://api.github.com/users/ivanovmg/events{/...
# 14  https://api.github.com/users/Hanspagh/events{/...
# 15  https://api.github.com/users/xhochy/events{/pr...
# 16  https://api.github.com/users/Flix6x/events{/pr...
# 17  https://api.github.com/users/xuancong84/events...
# 18  https://api.github.com/users/eromoe/events{/pr...
# 19  https://api.github.com/users/jbrockmendel/even...
# 20  https://api.github.com/users/rhshadrach/events...
# 21  https://api.github.com/users/jbrockmendel/even...
# 22  https://api.github.com/users/phofl/events{/pri...
# 23  https://api.github.com/users/phofl/events{/pri...
# 24  https://api.github.com/users/phofl/events{/pri...
# 25  https://api.github.com/users/jbrockmendel/even...
# 26  https://api.github.com/users/gabrielecalvo/eve...
# 27  https://api.github.com/users/notestaff/events{...
# 28  https://api.github.com/users/jbrockmendel/even...
# 29  https://api.github.com/users/asishm/events{/pr...
#
#                              user.received_events_url user.type  \
# 0   https://api.github.com/users/jbrockmendel/rece...      User
# 1   https://api.github.com/users/wumpus/received_e...      User
# 2   https://api.github.com/users/jbrockmendel/rece...      User
# 3   https://api.github.com/users/wumpus/received_e...      User
# 4   https://api.github.com/users/phofl/received_ev...      User
# 5   https://api.github.com/users/Quetzalcohuatl/re...      User
# 6   https://api.github.com/users/jbrockmendel/rece...      User
# 7   https://api.github.com/users/machow/received_e...      User
# 8   https://api.github.com/users/jbrockmendel/rece...      User
# 9   https://api.github.com/users/tbachlechner/rece...      User
# 10  https://api.github.com/users/jbrockmendel/rece...      User
# 11  https://api.github.com/users/tbachlechner/rece...      User
# 12  https://api.github.com/users/ivanovmg/received...      User
# 13  https://api.github.com/users/ivanovmg/received...      User
# 14  https://api.github.com/users/Hanspagh/received...      User
# 15  https://api.github.com/users/xhochy/received_e...      User
# 16  https://api.github.com/users/Flix6x/received_e...      User
# 17  https://api.github.com/users/xuancong84/receiv...      User
# 18  https://api.github.com/users/eromoe/received_e...      User
# 19  https://api.github.com/users/jbrockmendel/rece...      User
# 20  https://api.github.com/users/rhshadrach/receiv...      User
# 21  https://api.github.com/users/jbrockmendel/rece...      User
# 22  https://api.github.com/users/phofl/received_ev...      User
# 23  https://api.github.com/users/phofl/received_ev...      User
# 24  https://api.github.com/users/phofl/received_ev...      User
# 25  https://api.github.com/users/jbrockmendel/rece...      User
# 26  https://api.github.com/users/gabrielecalvo/rec...      User
# 27  https://api.github.com/users/notestaff/receive...      User
# 28  https://api.github.com/users/jbrockmendel/rece...      User
# 29  https://api.github.com/users/asishm/received_e...      User
#
#     user.site_admin
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False
# 15            False
# 16            False
# 17            False
# 18            False
# 19            False
# 20            False
# 21            False
# 22            False
# 23            False
# 24            False
# 25            False
# 26            False
# 27            False
# 28            False
# 29            False

# %%
data[1]['labels']
# Out:
# [{'id': 1954720290,
#   'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#   'name': 'Needs Triage',
#   'color': '0052cc',
#   'default': False,
#   'description': 'Issue that has not been reviewed by a pandas team member'},
#  {'id': 34444536,
#   'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#   'name': 'Usage Question',
#   'color': '0052cc',
#   'default': False,
#   'description': None}]

# %%
a=pd.DataFrame(data[1]['labels'])
a
# Out:
#            id                   node_id  \
# 0  1954720290  MDU6TGFiZWwxOTU0NzIwMjkw
# 1    34444536  MDU6TGFiZWwzNDQ0NDUzNg==
#
#                                                  url            name   color  \
# 0  https://api.github.com/repos/pandas-dev/pandas...    Needs Triage  0052cc
# 1  https://api.github.com/repos/pandas-dev/pandas...  Usage Question  0052cc
#
#    default                                        description
# 0    False  Issue that has not been reviewed by a pandas t...
# 1    False                                               None

# %%
d=pd.DataFrame(data[29]['labels'])
d
# Out:
#          id                   node_id  \
# 0     76811      MDU6TGFiZWw3NjgxMQ==
# 1  78527356  MDU6TGFiZWw3ODUyNzM1Ng==
# 2  57522093  MDU6TGFiZWw1NzUyMjA5Mw==
#
#                                                  url         name   color  \
# 0  https://api.github.com/repos/pandas-dev/pandas...          Bug  e10c02
# 1  https://api.github.com/repos/pandas-dev/pandas...  Categorical  e11d21
# 2  https://api.github.com/repos/pandas-dev/pandas...      Strings  5319e7
#
#    default                                 description
# 0    False                                        None
# 1    False                       Categorical Data Type
# 2    False  String extension data type and string data
